# %%
import networkx as nx
import pandas as pd
#import sys
#!{sys.executable} -m pip install colorgram.py
import colorgram
import numpy as np
from PIL import Image, ImageFont, ImageDraw
import matplotlib.pyplot as plt
import re
from base64 import b16encode
import requests
from io import BytesIO
import urllib.request
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Created a CSV with some other logos
col_names = ['logo_path','team']
Logos = pd.read_csv('https://raw.githubusercontent.com/PLombardo811/620/Project-1/Logos_csv.csv')

# %%
logo_path = Logos.logo_path
team = Logos.team
league = Logos.league

# %%
colors = []
for i in logo_path:
    URL = urllib.request.urlopen(i)
    colors.append(colorgram.extract(URL,6))

# %%
def GetMyColors(color):
   color_return = []
   for each_color in color[:3]:
       color_string = str(each_color.rgb)
       color_int = (re.findall(r'\d+', color_string))
       color_return.append(color_int)
   return(color_return)

# %%
team_colors = {}
for i in list(range(len(team))):
    team_colors[team[i]] = GetMyColors(colors[i])

# %%
RGBList = []
for i in colors:
   RGBList.append(GetMyColors(i))

# %%
df = pd.DataFrame(list(RGBList),columns=["Color_1", "Color_2", "Color_3"]) 
df = df.set_value(25, "Color_3", [255,255,255])

# %%
top_3_colors = []
for each_column in df.columns.tolist():
    top_3_colors.append([list(map(int, x)) for x in df[each_column]])

hexes = []

def Hex(rgbcolor):
    hex_return = []
    for each_color in rgbcolor:
        hex_color = (b"#" + b16encode(bytes(each_color)))
        hex_return.append(hex_color)
    return(hex_return)

for each_color in top_3_colors:
    hexes.append(Hex(each_color))

# %%
df['league'] = league
df['team'] = team_colors
for i in range(3):
    df["hex_"+str(i+1)] = hexes[i]
    df["edges_"+str(i+1)] = df.apply(lambda x: (x["team"], x["hex_"+str(i+1)]), axis=1)
df
# Out:
#             Color_1          Color_2          Color_3 league team       hex_1  \
# 0   [254, 254, 254]     [232, 0, 51]     [0, 51, 142]     AL  NYY  b'#FEFEFE'
# 1   [254, 254, 254]        [4, 2, 4]     [251, 78, 4]     AL  BAL  b'#FEFEFE'
# 2   [254, 254, 254]     [202, 6, 41]  [252, 254, 252]     AL  BOS  b'#FEFEFE'
# 3   [254, 254, 254]     [29, 29, 29]  [135, 140, 142]     AL  CWS  b'#FEFEFE'
# 4   [255, 255, 255]     [214, 0, 44]  [223, 126, 149]     AL  CLE  b'#FFFFFF'
# 5   [254, 254, 254]      [0, 33, 71]  [224, 228, 233]     AL  DET  b'#FEFEFE'
# 6       [0, 33, 71]  [254, 254, 254]    [213, 73, 42]     AL  HOU  b'#002147'
# 7   [254, 254, 254]     [0, 43, 115]   [133, 113, 76]     AL   KC  b'#FEFEFE'
# 8   [254, 254, 254]    [161, 25, 52]      [0, 32, 67]     AL  LAA  b'#FEFEFE'
# 9       [0, 33, 68]  [255, 255, 255]    [187, 15, 52]     AL  MIN  b'#002144'
# 10  [254, 254, 254]      [0, 68, 56]   [253, 182, 16]     AL  OAK  b'#FEFEFE'
# 11  [255, 255, 255]      [0, 33, 68]  [133, 137, 140]     AL  SEA  b'#FFFFFF'
# 12  [255, 254, 254]      [0, 30, 67]  [106, 179, 230]     AL   TB  b'#FFFEFE'
# 13  [254, 254, 254]     [0, 43, 117]    [189, 14, 51]     AL  TEX  b'#FEFEFE'
# 14  [255, 255, 255]    [27, 69, 157]    [236, 31, 50]     AL  TOR  b'#FFFFFF'
# 15  [251, 254, 251]    [167, 21, 42]     [45, 41, 37]     NL  ARI  b'#FBFEFB'
# 16  [254, 254, 254]     [11, 35, 64]    [182, 12, 47]     NL  ATL  b'#FEFEFE'
# 17  [254, 254, 254]     [0, 51, 120]     [204, 8, 46]     NL  CHC  b'#FEFEFE'
# 18  [254, 254, 254]    [189, 14, 51]     [28, 28, 28]     NL  CIN  b'#FEFEFE'
# 19  [254, 254, 254]     [29, 29, 29]  [132, 136, 139]     NL  COL  b'#FEFEFE'
# 20  [254, 254, 254]    [34, 59, 117]    [231, 29, 53]     NL  LAD  b'#FEFEFE'
# 21  [254, 254, 254]  [131, 137, 141]    [1, 120, 201]     NL  MIA  b'#FEFEFE'
# 22  [254, 254, 254]     [18, 40, 74]   [132, 112, 76]     NL  MIL  b'#FEFEFE'
# 23  [254, 254, 253]     [0, 44, 116]     [254, 74, 0]     NL  NYM  b'#FEFEFD'
# 24  [254, 254, 254]    [185, 11, 46]     [0, 47, 134]     NL  PHI  b'#FEFEFE'
# 25  [255, 254, 254]   [255, 200, 46]  [255, 255, 255]     NL  PIT  b'#FFFEFE'
# 26     [14, 35, 70]  [255, 255, 255]  [137, 148, 165]     NL   SD  b'#0E2346'
# 27  [253, 251, 248]     [42, 39, 34]    [253, 72, 25]     NL   SF  b'#FDFBF8'
# 28  [254, 254, 254]    [184, 12, 47]     [11, 34, 63]     NL  STL  b'#FEFEFE'
# 29  [254, 254, 254]      [0, 29, 68]     [187, 5, 40]     NL  WAS  b'#FEFEFE'
#
#               edges_1       hex_2            edges_2       hex_3  \
# 0   (NYY, b'#FEFEFE')  b'#E80033'  (NYY, b'#E80033')  b'#00338E'
# 1   (BAL, b'#FEFEFE')  b'#040204'  (BAL, b'#040204')  b'#FB4E04'
# 2   (BOS, b'#FEFEFE')  b'#CA0629'  (BOS, b'#CA0629')  b'#FCFEFC'
# 3   (CWS, b'#FEFEFE')  b'#1D1D1D'  (CWS, b'#1D1D1D')  b'#878C8E'
# 4   (CLE, b'#FFFFFF')  b'#D6002C'  (CLE, b'#D6002C')  b'#DF7E95'
# 5   (DET, b'#FEFEFE')  b'#002147'  (DET, b'#002147')  b'#E0E4E9'
# 6   (HOU, b'#002147')  b'#FEFEFE'  (HOU, b'#FEFEFE')  b'#D5492A'
# 7    (KC, b'#FEFEFE')  b'#002B73'   (KC, b'#002B73')  b'#85714C'
# 8   (LAA, b'#FEFEFE')  b'#A11934'  (LAA, b'#A11934')  b'#002043'
# 9   (MIN, b'#002144')  b'#FFFFFF'  (MIN, b'#FFFFFF')  b'#BB0F34'
# 10  (OAK, b'#FEFEFE')  b'#004438'  (OAK, b'#004438')  b'#FDB610'
# 11  (SEA, b'#FFFFFF')  b'#002144'  (SEA, b'#002144')  b'#85898C'
# 12   (TB, b'#FFFEFE')  b'#001E43'   (TB, b'#001E43')  b'#6AB3E6'
# 13  (TEX, b'#FEFEFE')  b'#002B75'  (TEX, b'#002B75')  b'#BD0E33'
# 14  (TOR, b'#FFFFFF')  b'#1B459D'  (TOR, b'#1B459D')  b'#EC1F32'
# 15  (ARI, b'#FBFEFB')  b'#A7152A'  (ARI, b'#A7152A')  b'#2D2925'
# 16  (ATL, b'#FEFEFE')  b'#0B2340'  (ATL, b'#0B2340')  b'#B60C2F'
# 17  (CHC, b'#FEFEFE')  b'#003378'  (CHC, b'#003378')  b'#CC082E'
# 18  (CIN, b'#FEFEFE')  b'#BD0E33'  (CIN, b'#BD0E33')  b'#1C1C1C'
# 19  (COL, b'#FEFEFE')  b'#1D1D1D'  (COL, b'#1D1D1D')  b'#84888B'
# 20  (LAD, b'#FEFEFE')  b'#223B75'  (LAD, b'#223B75')  b'#E71D35'
# 21  (MIA, b'#FEFEFE')  b'#83898D'  (MIA, b'#83898D')  b'#0178C9'
# 22  (MIL, b'#FEFEFE')  b'#12284A'  (MIL, b'#12284A')  b'#84704C'
# 23  (NYM, b'#FEFEFD')  b'#002C74'  (NYM, b'#002C74')  b'#FE4A00'
# 24  (PHI, b'#FEFEFE')  b'#B90B2E'  (PHI, b'#B90B2E')  b'#002F86'
# 25  (PIT, b'#FFFEFE')  b'#FFC82E'  (PIT, b'#FFC82E')  b'#FFFFFF'
# 26   (SD, b'#0E2346')  b'#FFFFFF'   (SD, b'#FFFFFF')  b'#8994A5'
# 27   (SF, b'#FDFBF8')  b'#2A2722'   (SF, b'#2A2722')  b'#FD4819'
# 28  (STL, b'#FEFEFE')  b'#B80C2F'  (STL, b'#B80C2F')  b'#0B223F'
# 29  (WAS, b'#FEFEFE')  b'#001D44'  (WAS, b'#001D44')  b'#BB0528'
#
#               edges_3
# 0   (NYY, b'#00338E')
# 1   (BAL, b'#FB4E04')
# 2   (BOS, b'#FCFEFC')
# 3   (CWS, b'#878C8E')
# 4   (CLE, b'#DF7E95')
# 5   (DET, b'#E0E4E9')
# 6   (HOU, b'#D5492A')
# 7    (KC, b'#85714C')
# 8   (LAA, b'#002043')
# 9   (MIN, b'#BB0F34')
# 10  (OAK, b'#FDB610')
# 11  (SEA, b'#85898C')
# 12   (TB, b'#6AB3E6')
# 13  (TEX, b'#BD0E33')
# 14  (TOR, b'#EC1F32')
# 15  (ARI, b'#2D2925')
# 16  (ATL, b'#B60C2F')
# 17  (CHC, b'#CC082E')
# 18  (CIN, b'#1C1C1C')
# 19  (COL, b'#84888B')
# 20  (LAD, b'#E71D35')
# 21  (MIA, b'#0178C9')
# 22  (MIL, b'#84704C')
# 23  (NYM, b'#FE4A00')
# 24  (PHI, b'#002F86')
# 25  (PIT, b'#FFFFFF')
# 26   (SD, b'#8994A5')
# 27   (SF, b'#FD4819')
# 28  (STL, b'#0B223F')
# 29  (WAS, b'#BB0528')

# %%
#G = nx.Graph()
#G.add_edges_from(df["team"].tolist())

# %%
unique_colors = list(set(df["hex_1"].tolist() + df["hex_2"].tolist() + df["hex_3"].tolist())) # if we don't need this, remove it
# Out:
# 61

# %%
G = nx.Graph()
G.add_edges_from(df["edges_1"].tolist() + df["edges_2"].tolist() + df["edges_3"].tolist())
G.add_nodes_from(df["team"].tolist()+df["hex_1"].tolist() + df["hex_2"].tolist() + df["hex_3"].tolist())
nx.draw(G)

# %%
pos = nx.spring_layout(G,k=1.55,iterations=80)
plt.figure(figsize=(20,20))
nx.draw_networkx_labels(G, pos, font_color='Blue')
nx.draw_networkx_edges(G, pos, edge_color="Gray", alpha=0.5)
nx.draw_networkx_nodes(G, pos)
plt.axis('off')
plt.show()
