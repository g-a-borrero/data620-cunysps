# %%
import networkx as nx
import pandas as pd
import matplotlib as plt
import colorgram
import numpy as np
from PIL import Image, ImageFont, ImageDraw
import matplotlib.pyplot as plt
import re
from base64 import b16encode
import requests
from io import BytesIO
import urllib.request
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Created a CSV with some other logos
col_names = ['logo_path','team']
Logos = pd.read_csv('https://raw.githubusercontent.com/PLombardo811/620/Project-1/Logos_csv.csv')

# %%
logo_path = Logos.logo_path

team = Logos.team
league = Logos.league

# %%
colors = []
for i in logo_path:
    URL = urllib.request.urlopen(i)
    colors.append(colorgram.extract(URL,6))

# %%
def GetMyColors(color):
   color_return = []
   for each_color in color[:3]:
       color_string = str(each_color.rgb)
       color_int = (re.findall(r'\d+', color_string))
       color_return.append(color_int)
   return(color_return)

# %%
team_colors = {}
for i in list(range(len(team))):
    team_colors[team[i]] = GetMyColors(colors[i])

# %%
RGBList = []
for i in colors:
   RGBList.append(GetMyColors(i))

# %%
df = pd.DataFrame(list(RGBList),columns=["Color_1", "Color_2", "Color_3"]) 
df = df.set_value(25, "Color_3", [255,255,255])

# %%
top_3_colors = []
for each_column in df.columns.tolist():
    top_3_colors.append([list(map(int, x)) for x in df[each_column]])

hexes = []

def Hex(rgbcolor):
    hex_return = []
    for each_color in rgbcolor:
        hex_color = (b"#" + b16encode(bytes(each_color)))
        hex_return.append(hex_color)
    return(hex_return)

for each_color in top_3_colors:
    hexes.append(Hex(each_color))

# %%
for i in range(3):
    df["hex_"+str(i)] = hexes[i]
df['league'] = league
df['team'] = team_colors
df
# Out:
#             Color_1          Color_2          Color_3       hex_0       hex_1  \
# 0   [254, 254, 254]     [232, 0, 51]     [0, 51, 142]  b'#FEFEFE'  b'#E80033'
# 1   [254, 254, 254]        [4, 2, 4]     [251, 78, 4]  b'#FEFEFE'  b'#040204'
# 2   [254, 254, 254]     [202, 6, 41]  [252, 254, 252]  b'#FEFEFE'  b'#CA0629'
# 3   [254, 254, 254]     [29, 29, 29]  [135, 140, 142]  b'#FEFEFE'  b'#1D1D1D'
# 4   [255, 255, 255]     [214, 0, 44]  [223, 126, 149]  b'#FFFFFF'  b'#D6002C'
# 5   [254, 254, 254]      [0, 33, 71]  [224, 228, 233]  b'#FEFEFE'  b'#002147'
# 6       [0, 33, 71]  [254, 254, 254]    [213, 73, 42]  b'#002147'  b'#FEFEFE'
# 7   [254, 254, 254]     [0, 43, 115]   [133, 113, 76]  b'#FEFEFE'  b'#002B73'
# 8   [254, 254, 254]    [161, 25, 52]      [0, 32, 67]  b'#FEFEFE'  b'#A11934'
# 9       [0, 33, 68]  [255, 255, 255]    [187, 15, 52]  b'#002144'  b'#FFFFFF'
# 10  [254, 254, 254]      [0, 68, 56]   [253, 182, 16]  b'#FEFEFE'  b'#004438'
# 11  [255, 255, 255]      [0, 33, 68]  [133, 137, 140]  b'#FFFFFF'  b'#002144'
# 12  [255, 254, 254]      [0, 30, 67]  [106, 179, 230]  b'#FFFEFE'  b'#001E43'
# 13  [254, 254, 254]     [0, 43, 117]    [189, 14, 51]  b'#FEFEFE'  b'#002B75'
# 14  [255, 255, 255]    [27, 69, 157]    [236, 31, 50]  b'#FFFFFF'  b'#1B459D'
# 15  [251, 254, 251]    [167, 21, 42]     [45, 41, 37]  b'#FBFEFB'  b'#A7152A'
# 16  [254, 254, 254]     [11, 35, 64]    [182, 12, 47]  b'#FEFEFE'  b'#0B2340'
# 17  [254, 254, 254]     [0, 51, 120]     [204, 8, 46]  b'#FEFEFE'  b'#003378'
# 18  [254, 254, 254]    [189, 14, 51]     [28, 28, 28]  b'#FEFEFE'  b'#BD0E33'
# 19  [254, 254, 254]     [29, 29, 29]  [132, 136, 139]  b'#FEFEFE'  b'#1D1D1D'
# 20  [254, 254, 254]    [34, 59, 117]    [231, 29, 53]  b'#FEFEFE'  b'#223B75'
# 21  [254, 254, 254]  [131, 137, 141]    [1, 120, 201]  b'#FEFEFE'  b'#83898D'
# 22  [254, 254, 254]     [18, 40, 74]   [132, 112, 76]  b'#FEFEFE'  b'#12284A'
# 23  [254, 254, 253]     [0, 44, 116]     [254, 74, 0]  b'#FEFEFD'  b'#002C74'
# 24  [254, 254, 254]    [185, 11, 46]     [0, 47, 134]  b'#FEFEFE'  b'#B90B2E'
# 25  [255, 254, 254]   [255, 200, 46]  [255, 255, 255]  b'#FFFEFE'  b'#FFC82E'
# 26     [14, 35, 70]  [255, 255, 255]  [137, 148, 165]  b'#0E2346'  b'#FFFFFF'
# 27  [253, 251, 248]     [42, 39, 34]    [253, 72, 25]  b'#FDFBF8'  b'#2A2722'
# 28  [254, 254, 254]    [184, 12, 47]     [11, 34, 63]  b'#FEFEFE'  b'#B80C2F'
# 29  [254, 254, 254]      [0, 29, 68]     [187, 5, 40]  b'#FEFEFE'  b'#001D44'
#
#          hex_2 league team
# 0   b'#00338E'     AL  NYY
# 1   b'#FB4E04'     AL  BAL
# 2   b'#FCFEFC'     AL  BOS
# 3   b'#878C8E'     AL  CWS
# 4   b'#DF7E95'     AL  CLE
# 5   b'#E0E4E9'     AL  DET
# 6   b'#D5492A'     AL  HOU
# 7   b'#85714C'     AL   KC
# 8   b'#002043'     AL  LAA
# 9   b'#BB0F34'     AL  MIN
# 10  b'#FDB610'     AL  OAK
# 11  b'#85898C'     AL  SEA
# 12  b'#6AB3E6'     AL   TB
# 13  b'#BD0E33'     AL  TEX
# 14  b'#EC1F32'     AL  TOR
# 15  b'#2D2925'     NL  ARI
# 16  b'#B60C2F'     NL  ATL
# 17  b'#CC082E'     NL  CHC
# 18  b'#1C1C1C'     NL  CIN
# 19  b'#84888B'     NL  COL
# 20  b'#E71D35'     NL  LAD
# 21  b'#0178C9'     NL  MIA
# 22  b'#84704C'     NL  MIL
# 23  b'#FE4A00'     NL  NYM
# 24  b'#002F86'     NL  PHI
# 25  b'#FFFFFF'     NL  PIT
# 26  b'#8994A5'     NL   SD
# 27  b'#FD4819'     NL   SF
# 28  b'#0B223F'     NL  STL
# 29  b'#BB0528'     NL  WAS

# %%
df["edges"] = df.apply(lambda x: (x["team"], x["hex_1"], x["hex_2"]), axis=1)

# %%
G = nx.Graph()
G.add_edges_from(df["edges"].tolist())
G.add_nodes_from(df["team"].tolist()+df["hex_1"].tolist() + df["hex_2"].tolist())
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-6a2df039af52> in <module>()
#       1 G = nx.Graph()
# ----> 2 G.add_edges_from(df["edges"].tolist())
#       3 G.add_nodes_from(df["team"].tolist()+df["hex_1"].tolist() + df["hex_2"].tolist())
#       4 nx.draw(G)
#
# ~\Anaconda3\lib\site-packages\networkx\classes\graph.py in add_edges_from(self, ebunch_to_add, **attr)
#     941             datadict = self._adj[u].get(v, self.edge_attr_dict_factory())
#     942             datadict.update(attr)
# --> 943             datadict.update(dd)
#     944             self._adj[u][v] = datadict
#     945             self._adj[v][u] = datadict
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
pos = nx.spring_layout(G,k=1.55,iterations=80)
plt.figure(figsize=(20,20))
nx.draw_networkx_labels(G, pos, font_color='Blue')
nx.draw_networkx_edges(G, pos, edge_color="Gray", alpha=0.3)
nx.draw_networkx_nodes(G, pos)
plt.axis('off')
plt.show()
